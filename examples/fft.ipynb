# %%
using SciPy
using PyPlot

# %%
t = collect(0:256)
sp = fft.fftshift(fft.fft(sin.(t)))
freq = fft.fftshift(fft.fftfreq(size(t)[end]))
plot(freq, real(sp), freq, imag(sp))
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 2-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fb3ce8055f8>
#  PyObject <matplotlib.lines.Line2D object at 0x7fb3ce805748>
